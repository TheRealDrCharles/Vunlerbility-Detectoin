# %%
# -*- coding: utf-8 -*-
"""
The input of this file are the extracted ASTs (serialized) outputed by CodeSensor.
The output of this file are the textual sequence of ASTs.
"""

import os
import time

Project_Name = "/LibPNG"

Vulnerble = '/Vulnerable_functions'

Non_Vulnerble = '/Non_vulnerable_functions'

Working_directory = "/Users/charleswayne/Downloads/preprocessing_data"

FILE_PATH = Working_directory + Project_Name + Vulnerble + '/ASTs/'

Processed_FILE = Working_directory + Project_Name + Vulnerble + '/processed/'

def processing(s):
    s = s.split()
    new_str = ''
    for x in s:
        x = ''.join(x)
        new_str += x
        new_str += '_'
    return new_str[:-1]
def DepthFirstExtractASTs(file_to_process, file_name):
    lines = []
    subLines = ''
    f = open(file_to_process)
    try:
        original_lines = f.readlines()
        lines.append(file_name) # The first element is the file name.
        for line in original_lines:
            if not line.isspace(): # Remove the empty line.
                line = line.strip('\n')
                str_lines = line.split('\t')   
                if str_lines[0] != "water": # Remove lines starting with water.
                    if str_lines[0] == 'LEAF_NODE':
                        res = processing(str_lines[4])
                        lines.append(res)
                    
#                         if str_lines[4] == "+":
#                             lines.append('+')
#                         if str_lines[4] == "-":
#                             lines.append('-')
#                         if str_lines[4] == "*":
#                             lines.append('*')
#                         if str_lines[4] == "/":
#                             lines.append('/')
#                         if str_lines[4] == "%":
#                             lines.append('%')
#                         if str_lines[4] == "++":
#                             lines.append('++')
#                         if str_lines[4] == "--":
#                             lines.append('--')
#                         if str_lines[4] == "=":
#                             lines.append('=')
#                         if str_lines[4] == "==":
#                             lines.append('==')
#                         if str_lines[4] == "!=":
#                             lines.append('!=')
#                         if str_lines[4] == ">":
#                             lines.append('>')
#                         if str_lines[4] == "<":
#                             lines.append('<')
#                         if str_lines[4] == ">=":
#                             lines.append('>=')
#                         if str_lines[4] == "<=":
#                             lines.append('<=')
#                         if str_lines[4] == "&&":
#                             lines.append('&&')
#                         if str_lines[4] == "||":
#                             lines.append('||')
#                         if str_lines[4] == "&":
#                             lines.append('&')
#                         if str_lines[4] == "|":
#                             lines.append('|')
#                         if str_lines[4] == "^":
#                             lines.append('^')
#                         if str_lines[4] == "~":
#                             lines.append('~')
#                         if str_lines[4] == "<<":
#                             lines.append('<<')
#                         if str_lines[4] == ">>":
#                             lines.append('>>')
#                         if str_lines[4] == "+=":
#                             lines.append('+=')
#                         if str_lines[4] == "-=":
#                             lines.append('-=')
#                         if str_lines[4] == "*=":
#                             lines.append('*=')
#                         if str_lines[4] == "/=":
#                             lines.append('/=')
#                         if str_lines[4] == "%=":
#                             lines.append('%=')
#                         if str_lines[4] == "<<=":
#                             lines.append('<<=')
#                         if str_lines[4] == ">>=":
#                             lines.append('>>=')
#                         if str_lines[4] == "&=":
#                             lines.append('&=')
#                         if str_lines[4] == "^=":
#                             lines.append('^=')
#                         if str_lines[4] == "|=":
#                             lines.append('|=')
#                         if str_lines[4] == "?:":
#                             lines.append('?:')
#                         if str_lines[4] == "[":
#                             lines.append('[')
#                         if str_lines[4] == "]":
#                             lines.append(']')
#                         if str_lines[4] == ".":
#                             lines.append('.')
#                         if str_lines[4] == "\n":
#                             lines.append('line_return') # Specifying the ending of each function.
#                         if str_lines[4] == "u_long":
#                             lines.append('u_long')
#                         if str_lines[4] == "u_char":
#                             lines.append('u_char')
#                         if str_lines[4] == "uint8":
#                             lines.append('uint8')
#                         if str_lines[4] == "uint16":
#                             lines.append('uint16')
#                         if str_lines[4] == "uint32":
#                             lines.append('uint32')
#                         if str_lines[4] == "char":
#                             lines.append('char')
#                         if str_lines[4] == "signed":
#                             lines.append('signed')
#                         if str_lines[4] == "unsigned":
#                             lines.append('unsigned')
#                         if str_lines[4] == "short":
#                             lines.append('short')
#                         if str_lines[4] == "long":
#                             lines.append('long')
#                         if str_lines[4] == "float":
#                             lines.append('float')
#                         if str_lines[4] == "double":
#                             lines.append('double')
#                         if str_lines[4] == "const":
#                             lines.append('const')
#                         if str_lines[4] == "goto":
#                             lines.append('goto')
#                         if str_lines[4] == "sizeof":
#                             lines.append('sizeof')
#                         if str_lines[4] == "typedef":
#                             lines.append('typedef')
#                         if str_lines[4] == "enum":
#                             lines.append('enum')
#                         if str_lines[4] == "register":
#                             lines.append('register')
#                         if str_lines[4] == "union":
#                             lines.append('union')
#                         if str_lines[4] == "switch":
#                             lines.append('switch')
#                         if str_lines[4] == "default":
#                             lines.append('default')
#                         if str_lines[4] == "static":
#                             lines.append('static')
#                         if str_lines[4] == "int":
#                             lines.append('int')
#                         if str_lines[4] == "if":
#                             lines.append('if')
#                         if str_lines[4] == "else":
#                             lines.append('else')
#                         if str_lines[4] == "while":
#                             lines.append('while')
#                         if str_lines[4] == "do":
#                             lines.append('do')
#                         if str_lines[4] == "for":
#                             lines.append('for')
#                         if str_lines[4] == "return":
#                             lines.append('return')
#                         if str_lines[4] == "call":
#                             lines.append('call')
#                         if str_lines[4] == "continue":
#                             lines.append('continue')
#                         if str_lines[4] == "break":
#                             lines.append('break')
#                         if str_lines[4] == '*':
#                             lines.append('*')
#                         if str_lines[4] == '* *':
#                             lines.append('* *')
                            
                    if str_lines[0] == 'CALLEE': 
                        lines.append('callee')
                    if str_lines[0] == 'FUNCTION_NAME':
                        lines.append("function_name")
                    if str_lines[0] == 'ARGUMENT': 
                        lines.append('argument')
                    if str_lines[0] == 'ITERATION': 
                        lines.append('iteration')
                    if str_lines[0] == "PARAMETER_DECL":
                        lines.append('parameter_decl')     
                    if str_lines[0] == "VAR_DECL":
                        lines.append('car_decl')     
                    if str_lines[0] == 'EXPR':
                        lines.append('expr')   
                    if str_lines[0] == 'FUNCTION_CALL':
                        lines.append('function_call')
                    if str_lines[0] == 'ASSIGN_OP':
                        lines.append('assign_op')
                   
                    
                    
        subLines = ','.join(lines)
        subLines = subLines + "," + "\n"
    finally:
        f.close()
        return subLines
 
    
big_line = []
total_processed = 0

for fpathe,dirs,fs in os.walk(FILE_PATH):
    for f in fs:
        if os.path.splitext(f)[1]=='.txt':
            
            file_path = os.path.join(fpathe,f)
            res = DepthFirstExtractASTs(FILE_PATH + f, f)
            big_line.append(res)
            total_processed = total_processed + 1
            if res == '':
                print('the name is')
                print(f)
            print('none') if res == '' else print(res)
print ("Totally, there are " + str(total_processed) + " files.")
strResult = ''.join(big_line)
f1 = open(Processed_FILE + "/_proASTResult_DFT1.txt", "w")
f1.write(strResult)
f1.close()
# Out:
# cve-2004-0599-1.c.txt,void,function_name,png_handle_sPLT,(,parameter_decl,png_structp,png_ptr,,,parameter_decl,png_infop,info_ptr,,,parameter_decl,png_uint_32,length,),{,car_decl,png_bytep,chunkdata,;,car_decl,png_bytep,entry_start,;,car_decl,png_sPLT_t,new_palette,;,car_decl,png_sPLT_entryp,pp,;,car_decl,int,data_length,,,car_decl,int,entry_size,,,car_decl,int,i,;,car_decl,png_uint_32,skip,;,skip,assign_op,=,0,;,car_decl,png_size_t,slength,;,expr,function_call,callee,png_debug,(,argument,1,,,argument,"in png_handle_sPLT\n",),;,if,(,expr,!,(,png_ptr,->,mode,&,PNG_HAVE_IHDR,),),expr,function_call,callee,png_error,(,argument,png_ptr,,,argument,"Missing IHDR before sPLT",),;,else,if,(,expr,png_ptr,->,mode,&,PNG_HAVE_IDAT,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Invalid sPLT after IDAT",),;,expr,function_call,callee,png_crc_finish,(,argument,png_ptr,,,argument,length,),;,return,DESTINATION,;,},if,(,expr,length,>,(,png_uint_32,),65535L,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"sPLT chunk too large to fit in memory",),;,expr,skip,assign_op,=,length,-,(,png_uint_32,),65535L,;,expr,length,assign_op,=,(,png_uint_32,),65535L,;,},expr,chunkdata,assign_op,=,(,png_bytep,),function_call,callee,png_malloc,(,argument,png_ptr,,,argument,length,+,1,),;,expr,slength,assign_op,=,(,png_size_t,),length,;,expr,function_call,callee,png_crc_read,(,argument,png_ptr,,,argument,(,png_bytep,),chunkdata,,,argument,slength,),;,if,(,expr,function_call,callee,png_crc_finish,(,argument,png_ptr,,,argument,skip,),),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,chunkdata,),;,return,DESTINATION,;,},expr,chunkdata,[,expr,slength,],assign_op,=,0x00,;,iteration,for,(,expr,entry_start,assign_op,=,chunkdata,;,expr,*,entry_start,;,expr,entry_start,++,),;,expr,++,entry_start,;,if,(,expr,entry_start,>,chunkdata,+,slength,-,2,),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,chunkdata,),;,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"malformed sPLT chunk",),;,return,DESTINATION,;,},expr,new_palette,.,depth,assign_op,=,*,entry_start,++,;,expr,entry_size,assign_op,=,(,new_palette,.,depth,==,8,?,expr,6,:,10,),;,expr,data_length,assign_op,=,(,slength,-,(,entry_start,-,chunkdata,),),;,if,(,expr,data_length,%,entry_size,),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,chunkdata,),;,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"sPLT chunk has bad length",),;,return,DESTINATION,;,},expr,new_palette,.,nentries,assign_op,=,(,png_int_32,),(,data_length,/,entry_size,),;,if,(,expr,(,png_uint_32,),new_palette,.,nentries,>,(,png_uint_32,),(,PNG_SIZE_MAX,/,function_call,callee,png_sizeof,(,argument,png_sPLT_entry,),),),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"sPLT chunk too long",),;,return,DESTINATION,;,},expr,new_palette,.,entries,assign_op,=,(,png_sPLT_entryp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,new_palette,.,nentries,*,function_call,callee,png_sizeof,(,argument,png_sPLT_entry,),),;,if,(,expr,new_palette,.,entries,==,NULL,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"sPLT chunk requires too much memory",),;,return,DESTINATION,;,},iteration,for,(,expr,i,assign_op,=,0,;,expr,i,<,new_palette,.,nentries,;,expr,i,++,),{,car_decl,png_sPLT_entryp,pp,;,pp,assign_op,=,new_palette,.,entries,+,i,;,if,(,expr,new_palette,.,depth,==,8,),{,expr,pp,->,red,assign_op,=,*,entry_start,++,;,expr,pp,->,green,assign_op,=,*,entry_start,++,;,expr,pp,->,blue,assign_op,=,*,entry_start,++,;,expr,pp,->,alpha,assign_op,=,*,entry_start,++,;,},else,{,expr,pp,->,red,assign_op,=,function_call,callee,png_get_uint_16,(,argument,entry_start,),;,expr,entry_start,assign_op,+=,2,;,expr,pp,->,green,assign_op,=,function_call,callee,png_get_uint_16,(,argument,entry_start,),;,expr,entry_start,assign_op,+=,2,;,expr,pp,->,blue,assign_op,=,function_call,callee,png_get_uint_16,(, ...
#
# cve-2006-3334.c.txt,png_charp,function_name,png_decompress_chunk,(,parameter_decl,png_structp,png_ptr,,,parameter_decl,int,comp_type,,,parameter_decl,png_charp,chunkdata,,,parameter_decl,png_size_t,chunklength,,,parameter_decl,png_size_t,prefix_size,,,parameter_decl,png_size_t,*,newlength,),{,static,car_decl,char,[,],msg,;,msg,assign_op,=,"Error decoding compressed text",;,car_decl,png_charp,text,;,car_decl,png_size_t,text_size,;,if,(,expr,comp_type,==,PNG_COMPRESSION_TYPE_BASE,),{,car_decl,int,ret,;,ret,assign_op,=,Z_OK,;,expr,png_ptr,->,zstream,.,next_in,assign_op,=,(,png_bytep,),(,chunkdata,+,prefix_size,),;,expr,png_ptr,->,zstream,.,avail_in,assign_op,=,(,uInt,),(,chunklength,-,prefix_size,),;,expr,png_ptr,->,zstream,.,next_out,assign_op,=,png_ptr,->,zbuf,;,expr,png_ptr,->,zstream,.,avail_out,assign_op,=,(,uInt,),png_ptr,->,zbuf_size,;,expr,text_size,assign_op,=,0,;,expr,text,assign_op,=,NULL,;,iteration,while,(,expr,png_ptr,->,zstream,.,avail_in,),{,expr,ret,assign_op,=,function_call,callee,inflate,(,argument,&,png_ptr,->,zstream,,,argument,Z_PARTIAL_FLUSH,),;,if,(,expr,expr,ret,!=,Z_OK,&&,expr,ret,!=,Z_STREAM_END,),{,if,(,expr,png_ptr,->,zstream,.,msg,!=,NULL,),expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,png_ptr,->,zstream,.,msg,),;,else,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,msg,),;,expr,function_call,callee,inflateReset,(,argument,&,png_ptr,->,zstream,),;,expr,png_ptr,->,zstream,.,avail_in,assign_op,=,0,;,if,(,expr,text,==,NULL,),{,expr,text_size,assign_op,=,prefix_size,+,function_call,callee,png_sizeof,(,argument,msg,),+,1,;,expr,text,assign_op,=,(,png_charp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,text_size,),;,if,(,expr,text,==,NULL,),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,chunkdata,),;,expr,function_call,callee,png_error,(,argument,png_ptr,,,argument,"Not enough memory to decompress chunk",),;,},expr,function_call,callee,png_memcpy,(,argument,text,,,argument,chunkdata,,,argument,prefix_size,),;,},expr,text,[,expr,text_size,-,1,],assign_op,=,0x00,;,expr,text_size,assign_op,=,(,png_size_t,),(,chunklength,-,(,text,-,chunkdata,),-,1,),;,expr,text_size,assign_op,=,function_call,callee,png_sizeof,(,argument,msg,),>,text_size,?,expr,text_size,:,function_call,callee,png_sizeof,(,argument,msg,),;,expr,function_call,callee,png_memcpy,(,argument,text,+,prefix_size,,,argument,msg,,,argument,text_size,+,1,),;,break,DESTINATION,;,},if,(,expr,expr,!,png_ptr,->,zstream,.,avail_out,||,expr,ret,==,Z_STREAM_END,),{,if,(,expr,text,==,NULL,),{,expr,text_size,assign_op,=,prefix_size,+,png_ptr,->,zbuf_size,-,png_ptr,->,zstream,.,avail_out,;,expr,text,assign_op,=,(,png_charp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,text_size,+,1,),;,if,(,expr,text,==,NULL,),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,chunkdata,),;,expr,function_call,callee,png_error,(,argument,png_ptr,,,argument,"Not enough memory to decompress chunk.",),;,},expr,function_call,callee,png_memcpy,(,argument,text,+,prefix_size,,,argument,png_ptr,->,zbuf,,,argument,text_size,-,prefix_size,),;,expr,function_call,callee,png_memcpy,(,argument,text,,,argument,chunkdata,,,argument,prefix_size,),;,expr,*,(,text,+,text_size,),assign_op,=,0x00,;,},else,{,car_decl,png_charp,tmp,;,expr,tmp,assign_op,=,text,;,expr,text,assign_op,=,(,png_charp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,(,png_uint_32,),(,text_size,+,png_ptr,->,zbuf_size,-,png_ptr,->,zstream,.,avail_out,+,1,),),;,if,(,expr,text,==,NULL,),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,tmp,),;,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,chunkdata,),;,expr,function_call,callee,png_error,(,argument,png_ptr,,,argument,"Not enough memory to decompress chunk..",),;,},expr,function_call,callee,png_memcpy,(,argument,text,,,argument,tmp,,,argument,text_size,),;,expr,function_call,callee,png_free,(,argument,png ...
#
# cve-2011-3045.c.txt,static,png_size_t,function_name,png_inflate,(,parameter_decl,png_structp,png_ptr,,,parameter_decl,const,png_byte,*,data,,,parameter_decl,png_size_t,size,,,parameter_decl,png_bytep,output,,,parameter_decl,png_size_t,output_size,),{,car_decl,png_size_t,count,;,count,assign_op,=,0,;,expr,png_ptr,->,zstream,.,next_in,assign_op,=,(,png_bytep,),data,;,expr,png_ptr,->,zstream,.,avail_in,assign_op,=,size,;,iteration,while,(,expr,1,),{,car_decl,int,ret,,,car_decl,int,avail,;,expr,png_ptr,->,zstream,.,next_out,assign_op,=,png_ptr,->,zbuf,;,expr,png_ptr,->,zstream,.,avail_out,assign_op,=,png_ptr,->,zbuf_size,;,expr,ret,assign_op,=,function_call,callee,inflate,(,argument,&,png_ptr,->,zstream,,,argument,Z_NO_FLUSH,),;,expr,avail,assign_op,=,png_ptr,->,zbuf_size,-,png_ptr,->,zstream,.,avail_out,;,if,(,expr,expr,(,expr,ret,==,Z_OK,||,expr,ret,==,Z_STREAM_END,),&&,expr,avail,>,0,),{,if,(,expr,expr,output,!=,0,&&,expr,output_size,>,count,),{,car_decl,int,copy,;,copy,assign_op,=,output_size,-,count,;,if,(,expr,avail,<,copy,),expr,copy,assign_op,=,avail,;,expr,function_call,callee,png_memcpy,(,argument,output,+,count,,,argument,png_ptr,->,zbuf,,,argument,copy,),;,},expr,count,assign_op,+=,avail,;,},if,(,expr,ret,==,Z_OK,),continue,DESTINATION,;,expr,png_ptr,->,zstream,.,avail_in,assign_op,=,0,;,expr,function_call,callee,inflateReset,(,argument,&,png_ptr,->,zstream,),;,if,(,expr,ret,==,Z_STREAM_END,),return,expr,count,;,{,PNG_CONST,car_decl,char,*,msg,;,if,(,expr,png_ptr,->,zstream,.,msg,!=,0,),expr,msg,assign_op,=,png_ptr,->,zstream,.,msg,;,else,{,car_decl,char,[,52,],umsg,;,switch,(,expr,ret,),{,case,Z_BUF_ERROR,:,expr,msg,assign_op,=,"Buffer error in compressed datastream in %s chunk",;,break,DESTINATION,;,case,Z_DATA_ERROR,:,expr,msg,assign_op,=,"Data error in compressed datastream in %s chunk",;,break,DESTINATION,;,default,:,expr,msg,assign_op,=,"Incomplete compressed datastream in %s chunk",;,break,DESTINATION,;,},png_snprintf,(,umsg,,,sizeof,umsg,,,msg,,,png_ptr,->,chunk_name,),;,expr,msg,assign_op,=,umsg,;,expr,msg,assign_op,=,"Damaged compressed datastream in chunk other than IDAT",;,},expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,msg,),;,},return,expr,0,;,},},
#
# cve-2016-10087.c.txt,int,function_name,png_set_text_2,(,parameter_decl,png_const_structrp,png_ptr,,,parameter_decl,png_inforp,info_ptr,,,parameter_decl,png_const_textp,text_ptr,,,parameter_decl,int,num_text,),{,car_decl,int,i,;,expr,function_call,callee,png_debug1,(,argument,1,,,argument,"in %lx storage function",,,argument,png_ptr,==,NULL,?,expr,"unexpected",:,(,unsigned,long,),png_ptr,->,chunk_name,),;,if,(,expr,expr,png_ptr,==,NULL,||,expr,expr,info_ptr,==,NULL,||,expr,expr,num_text,<=,0,||,expr,text_ptr,==,NULL,),return,expr,(,0,),;,if,(,expr,num_text,>,info_ptr,->,max_text,-,info_ptr,->,num_text,),{,car_decl,int,old_num_text,;,old_num_text,assign_op,=,info_ptr,->,num_text,;,car_decl,int,max_text,;,car_decl,png_textp,new_text,;,new_text,assign_op,=,NULL,;,expr,max_text,assign_op,=,old_num_text,;,if,(,expr,num_text,<=,INT_MAX,-,max_text,),{,expr,max_text,assign_op,+=,num_text,;,if,(,expr,max_text,<,INT_MAX,-,8,),expr,max_text,assign_op,=,(,max_text,+,8,),&,~0x7,;,else,expr,max_text,assign_op,=,INT_MAX,;,expr,new_text,assign_op,=,function_call,callee,png_voidcast,(,argument,png_textp,,,argument,function_call,callee,png_realloc_array,(,argument,png_ptr,,,argument,info_ptr,->,text,,,argument,old_num_text,,,argument,max_text,-,old_num_text,,,argument,sizeof,*,new_text,),),;,},if,(,expr,new_text,==,NULL,),{,expr,function_call,callee,png_chunk_report,(,argument,png_ptr,,,argument,"too many text chunks",,,argument,PNG_CHUNK_WRITE_ERROR,),;,return,expr,1,;,},expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,info_ptr,->,text,),;,expr,info_ptr,->,text,assign_op,=,new_text,;,expr,info_ptr,->,free_me,assign_op,|=,PNG_FREE_TEXT,;,expr,info_ptr,->,max_text,assign_op,=,max_text,;,expr,function_call,callee,png_debug1,(,argument,3,,,argument,"allocated %d entries for info_ptr->text",,,argument,max_text,),;,},iteration,for,(,expr,i,assign_op,=,0,;,expr,i,<,num_text,;,expr,i,++,),{,car_decl,size_t,text_length,,,car_decl,size_t,key_len,;,car_decl,size_t,lang_len,,,car_decl,size_t,lang_key_len,;,car_decl,png_textp,textp,;,textp,assign_op,=,&,(,info_ptr,->,text,[,expr,info_ptr,->,num_text,],),;,if,(,expr,text_ptr,[,expr,i,],.,key,==,NULL,),continue,DESTINATION,;,if,(,expr,expr,text_ptr,[,expr,i,],.,compression,<,PNG_TEXT_COMPRESSION_NONE,||,expr,text_ptr,[,expr,i,],.,compression,>=,PNG_TEXT_COMPRESSION_LAST,),{,expr,function_call,callee,png_chunk_report,(,argument,png_ptr,,,argument,"text compression mode is out of range",,,argument,PNG_CHUNK_WRITE_ERROR,),;,continue,DESTINATION,;,},expr,key_len,assign_op,=,function_call,callee,strlen,(,argument,text_ptr,[,expr,i,],.,key,),;,if,(,expr,text_ptr,[,expr,i,],.,compression,<=,0,),{,expr,lang_len,assign_op,=,0,;,expr,lang_key_len,assign_op,=,0,;,},else,{,if,(,expr,text_ptr,[,expr,i,],.,lang,!=,NULL,),expr,lang_len,assign_op,=,function_call,callee,strlen,(,argument,text_ptr,[,expr,i,],.,lang,),;,else,expr,lang_len,assign_op,=,0,;,if,(,expr,text_ptr,[,expr,i,],.,lang_key,!=,NULL,),expr,lang_key_len,assign_op,=,function_call,callee,strlen,(,argument,text_ptr,[,expr,i,],.,lang_key,),;,else,expr,lang_key_len,assign_op,=,0,;,},{,expr,function_call,callee,png_chunk_report,(,argument,png_ptr,,,argument,"iTXt chunk not supported",,,argument,PNG_CHUNK_WRITE_ERROR,),;,continue,DESTINATION,;,},if,(,expr,expr,text_ptr,[,expr,i,],.,text,==,NULL,||,expr,text_ptr,[,expr,i,],.,text,[,expr,0,],==,'\0',),{,expr,text_length,assign_op,=,0,;,if,(,expr,text_ptr,[,expr,i,],.,compression,>,0,),expr,textp,->,compression,assign_op,=,PNG_ITXT_COMPRESSION_NONE,;,else,expr,textp,->,compression,assign_op,=,PNG_TEXT_COMPRESSION_NONE,;,},else,{,expr,text_length,assign_op,=,function_call,callee,strlen,(,argument,text_ptr,[,expr,i,],.,text,),;,expr,textp,->,compression,assign_op,=,text_ptr,[,expr,i,],.,compression,;,},expr,textp,->,key,assign_op,=,function_call,callee,png_voidcast,(,argument,png_charp,,,argument,function_call,callee,png_malloc_base,(,argument,png_ptr,,,argument,key_len,+,text_length,+,lang_len,+,lang_key ...
#
# cve-2010-0205.c.txt,png_charp,function_name,png_decompress_chunk,(,parameter_decl,png_structp,png_ptr,,,parameter_decl,int,comp_type,,,parameter_decl,png_charp,chunkdata,,,parameter_decl,png_size_t,chunklength,,,parameter_decl,png_size_t,prefix_size,,,parameter_decl,png_size_t,*,newlength,),{,static,car_decl,char,[,],msg,;,msg,assign_op,=,"Error decoding compressed text",;,car_decl,png_charp,text,;,car_decl,png_size_t,text_size,;,if,(,expr,comp_type,==,PNG_COMPRESSION_TYPE_BASE,),{,car_decl,int,ret,;,ret,assign_op,=,Z_OK,;,expr,png_ptr,->,zstream,.,next_in,assign_op,=,(,png_bytep,),(,chunkdata,+,prefix_size,),;,expr,png_ptr,->,zstream,.,avail_in,assign_op,=,(,uInt,),(,chunklength,-,prefix_size,),;,expr,png_ptr,->,zstream,.,next_out,assign_op,=,png_ptr,->,zbuf,;,expr,png_ptr,->,zstream,.,avail_out,assign_op,=,(,uInt,),png_ptr,->,zbuf_size,;,expr,text_size,assign_op,=,0,;,expr,text,assign_op,=,NULL,;,iteration,while,(,expr,png_ptr,->,zstream,.,avail_in,),{,expr,ret,assign_op,=,function_call,callee,inflate,(,argument,&,png_ptr,->,zstream,,,argument,Z_PARTIAL_FLUSH,),;,if,(,expr,expr,ret,!=,Z_OK,&&,expr,ret,!=,Z_STREAM_END,),{,if,(,expr,png_ptr,->,zstream,.,msg,!=,NULL,),expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,png_ptr,->,zstream,.,msg,),;,else,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,msg,),;,expr,function_call,callee,inflateReset,(,argument,&,png_ptr,->,zstream,),;,expr,png_ptr,->,zstream,.,avail_in,assign_op,=,0,;,if,(,expr,text,==,NULL,),{,expr,text_size,assign_op,=,prefix_size,+,function_call,callee,png_sizeof,(,argument,msg,),+,1,;,expr,text,assign_op,=,(,png_charp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,text_size,),;,if,(,expr,text,==,NULL,),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,chunkdata,),;,expr,function_call,callee,png_error,(,argument,png_ptr,,,argument,"Not enough memory to decompress chunk",),;,},expr,function_call,callee,png_memcpy,(,argument,text,,,argument,chunkdata,,,argument,prefix_size,),;,},expr,text,[,expr,text_size,-,1,],assign_op,=,0x00,;,expr,text_size,assign_op,=,(,png_size_t,),(,chunklength,-,(,text,-,chunkdata,),-,1,),;,expr,text_size,assign_op,=,function_call,callee,png_sizeof,(,argument,msg,),>,text_size,?,expr,text_size,:,function_call,callee,png_sizeof,(,argument,msg,),;,expr,function_call,callee,png_memcpy,(,argument,text,+,prefix_size,,,argument,msg,,,argument,text_size,+,1,),;,break,DESTINATION,;,},if,(,expr,expr,!,png_ptr,->,zstream,.,avail_out,||,expr,ret,==,Z_STREAM_END,),{,if,(,expr,text,==,NULL,),{,expr,text_size,assign_op,=,prefix_size,+,png_ptr,->,zbuf_size,-,png_ptr,->,zstream,.,avail_out,;,expr,text,assign_op,=,(,png_charp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,text_size,+,1,),;,if,(,expr,text,==,NULL,),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,chunkdata,),;,expr,function_call,callee,png_error,(,argument,png_ptr,,,argument,"Not enough memory to decompress chunk.",),;,},expr,function_call,callee,png_memcpy,(,argument,text,+,prefix_size,,,argument,png_ptr,->,zbuf,,,argument,text_size,-,prefix_size,),;,expr,function_call,callee,png_memcpy,(,argument,text,,,argument,chunkdata,,,argument,prefix_size,),;,expr,*,(,text,+,text_size,),assign_op,=,0x00,;,},else,{,car_decl,png_charp,tmp,;,expr,tmp,assign_op,=,text,;,expr,text,assign_op,=,(,png_charp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,(,png_uint_32,),(,text_size,+,png_ptr,->,zbuf_size,-,png_ptr,->,zstream,.,avail_out,+,1,),),;,if,(,expr,text,==,NULL,),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,tmp,),;,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,chunkdata,),;,expr,function_call,callee,png_error,(,argument,png_ptr,,,argument,"Not enough memory to decompress chunk..",),;,},expr,function_call,callee,png_memcpy,(,argument,text,,,argument,tmp,,,argument,text_size,),;,expr,function_call,callee,png_free,(,argument,png ...
#
# cve-2007-5266.c.txt,PNGAPI,function_name,png_set_iCCP,(,parameter_decl,png_structp,png_ptr,,,parameter_decl,png_infop,info_ptr,,,parameter_decl,png_charp,name,,,parameter_decl,int,compression_type,,,parameter_decl,png_charp,profile,,,parameter_decl,png_uint_32,proflen,),{,car_decl,png_charp,new_iccp_name,;,car_decl,png_charp,new_iccp_profile,;,expr,function_call,callee,png_debug1,(,argument,1,,,argument,"in %s storage function\n",,,argument,"iCCP",),;,if,(,expr,expr,png_ptr,==,NULL,||,expr,expr,info_ptr,==,NULL,||,expr,expr,name,==,NULL,||,expr,profile,==,NULL,),return,DESTINATION,;,expr,new_iccp_name,assign_op,=,(,png_charp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,function_call,callee,png_strlen,(,argument,name,),+,1,),;,if,(,expr,new_iccp_name,==,NULL,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Insufficient memory to process iCCP chunk.",),;,return,DESTINATION,;,},expr,function_call,callee,png_strcpy,(,argument,new_iccp_name,,,argument,name,),;,expr,new_iccp_profile,assign_op,=,(,png_charp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,proflen,),;,if,(,expr,new_iccp_profile,==,NULL,),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,new_iccp_name,),;,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Insufficient memory to process iCCP profile.",),;,return,DESTINATION,;,},expr,function_call,callee,png_memcpy,(,argument,new_iccp_profile,,,argument,profile,,,argument,(,png_size_t,),proflen,),;,expr,function_call,callee,png_free_data,(,argument,png_ptr,,,argument,info_ptr,,,argument,PNG_FREE_ICCP,,,argument,0,),;,expr,info_ptr,->,iccp_proflen,assign_op,=,proflen,;,expr,info_ptr,->,iccp_name,assign_op,=,new_iccp_name,;,expr,info_ptr,->,iccp_profile,assign_op,=,new_iccp_profile,;,expr,info_ptr,->,iccp_compression,assign_op,=,(,png_byte,),compression_type,;,expr,info_ptr,->,free_me,assign_op,|=,PNG_FREE_ICCP,;,expr,info_ptr,->,valid,assign_op,|=,PNG_INFO_iCCP,;,},
#
# cve-2013-7354-1.c.txt,PNGAPI,function_name,png_set_sPLT,(,parameter_decl,png_structp,png_ptr,,,parameter_decl,png_infop,info_ptr,,,parameter_decl,png_const_sPLT_tp,entries,,,parameter_decl,int,nentries,),{,car_decl,png_sPLT_tp,np,;,car_decl,int,i,;,if,(,expr,expr,png_ptr,==,NULL,||,expr,info_ptr,==,NULL,),return,DESTINATION,;,expr,np,assign_op,=,(,png_sPLT_tp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,(,info_ptr,->,splt_palettes_num,+,nentries,),*,(,png_size_t,),function_call,callee,png_sizeof,(,argument,png_sPLT_t,),),;,if,(,expr,np,==,NULL,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"No memory for sPLT palettes",),;,return,DESTINATION,;,},expr,function_call,callee,png_memcpy,(,argument,np,,,argument,info_ptr,->,splt_palettes,,,argument,info_ptr,->,splt_palettes_num,*,function_call,callee,png_sizeof,(,argument,png_sPLT_t,),),;,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,info_ptr,->,splt_palettes,),;,expr,info_ptr,->,splt_palettes,assign_op,=,NULL,;,iteration,for,(,expr,i,assign_op,=,0,;,expr,i,<,nentries,;,expr,i,++,),{,car_decl,png_sPLT_tp,to,;,to,assign_op,=,np,+,info_ptr,->,splt_palettes_num,+,i,;,car_decl,png_const_sPLT_tp,from,;,from,assign_op,=,entries,+,i,;,car_decl,png_size_t,length,;,expr,length,assign_op,=,function_call,callee,png_strlen,(,argument,from,->,name,),+,1,;,expr,to,->,name,assign_op,=,(,png_charp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,length,),;,if,(,expr,to,->,name,==,NULL,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Out of memory while processing sPLT chunk",),;,continue,DESTINATION,;,},expr,function_call,callee,png_memcpy,(,argument,to,->,name,,,argument,from,->,name,,,argument,length,),;,expr,to,->,entries,assign_op,=,(,png_sPLT_entryp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,from,->,nentries,*,function_call,callee,png_sizeof,(,argument,png_sPLT_entry,),),;,if,(,expr,to,->,entries,==,NULL,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Out of memory while processing sPLT chunk",),;,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,to,->,name,),;,expr,to,->,name,assign_op,=,NULL,;,continue,DESTINATION,;,},expr,function_call,callee,png_memcpy,(,argument,to,->,entries,,,argument,from,->,entries,,,argument,from,->,nentries,*,function_call,callee,png_sizeof,(,argument,png_sPLT_entry,),),;,expr,to,->,nentries,assign_op,=,from,->,nentries,;,expr,to,->,depth,assign_op,=,from,->,depth,;,},expr,info_ptr,->,splt_palettes,assign_op,=,np,;,expr,info_ptr,->,splt_palettes_num,assign_op,+=,nentries,;,expr,info_ptr,->,valid,assign_op,|=,PNG_INFO_sPLT,;,expr,info_ptr,->,free_me,assign_op,|=,PNG_FREE_SPLT,;,},
#
# cve-2015-8540.c.txt,png_size_t,function_name,png_check_keyword,(,parameter_decl,png_structp,png_ptr,,,parameter_decl,png_const_charp,key,,,parameter_decl,png_charpp,new_key,),{,car_decl,png_size_t,key_len,;,car_decl,png_const_charp,ikp,;,car_decl,png_charp,kp,,,car_decl,png_charp,dp,;,car_decl,int,kflag,;,car_decl,int,kwarn,;,kwarn,assign_op,=,0,;,expr,function_call,callee,png_debug,(,argument,1,,,argument,"in png_check_keyword",),;,expr,*,new_key,assign_op,=,NULL,;,if,(,expr,expr,key,==,NULL,||,expr,(,key_len,assign_op,=,function_call,callee,png_strlen,(,argument,key,),),==,0,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"zero length keyword",),;,return,expr,(,(,png_size_t,),0,),;,},expr,function_call,callee,png_debug1,(,argument,2,,,argument,"Keyword to be checked is '%s'",,,argument,key,),;,expr,*,new_key,assign_op,=,(,png_charp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,(,png_uint_32,),(,key_len,+,2,),),;,if,(,expr,*,new_key,==,NULL,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Out of memory while procesing keyword",),;,return,expr,(,(,png_size_t,),0,),;,},iteration,for,(,expr,ikp,assign_op,=,key,,,dp,assign_op,=,*,new_key,;,expr,*,ikp,!=,'\0',;,expr,ikp,++,,,dp,++,),{,if,(,expr,expr,(,png_byte,),*,ikp,<,0x20,||,expr,(,expr,(,png_byte,),*,ikp,>,0x7E,&&,expr,(,png_byte,),*,ikp,<,0xA1,),),{,PNG_WARNING_PARAMETERS,expr,(,p,),function_call,callee,png_warning_parameter_unsigned,(,argument,p,,,argument,1,,,argument,PNG_NUMBER_FORMAT_02x,,,argument,(,png_byte,),*,ikp,),;,expr,function_call,callee,png_formatted_warning,(,argument,png_ptr,,,argument,p,,,argument,"invalid keyword character 0x@1",),;,expr,*,dp,assign_op,=,' ',;,},else,{,expr,*,dp,assign_op,=,*,ikp,;,},},expr,*,dp,assign_op,=,'\0',;,expr,kp,assign_op,=,*,new_key,+,key_len,-,1,;,if,(,expr,*,kp,==,' ',),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"trailing spaces removed from keyword",),;,iteration,while,(,expr,*,kp,==,' ',),{,expr,*,(,kp,--,),assign_op,=,'\0',;,expr,key_len,--,;,},},expr,kp,assign_op,=,*,new_key,;,if,(,expr,*,kp,==,' ',),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"leading spaces removed from keyword",),;,iteration,while,(,expr,*,kp,==,' ',),{,expr,kp,++,;,expr,key_len,--,;,},},expr,function_call,callee,png_debug1,(,argument,2,,,argument,"Checking for multiple internal spaces in '%s'",,,argument,kp,),;,iteration,for,(,expr,kflag,assign_op,=,0,,,dp,assign_op,=,*,new_key,;,expr,*,kp,!=,'\0',;,expr,kp,++,),{,if,(,expr,expr,*,kp,==,' ',&&,expr,kflag,==,0,),{,expr,*,(,dp,++,),assign_op,=,*,kp,;,expr,kflag,assign_op,=,1,;,},else,if,(,expr,*,kp,==,' ',),{,expr,key_len,--,;,expr,kwarn,assign_op,=,1,;,},else,{,expr,*,(,dp,++,),assign_op,=,*,kp,;,expr,kflag,assign_op,=,0,;,},},expr,*,dp,assign_op,=,'\0',;,if,(,expr,kwarn,),expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"extra interior spaces removed from keyword",),;,if,(,expr,key_len,==,0,),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,*,new_key,),;,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Zero length keyword",),;,},if,(,expr,key_len,>,79,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"keyword length must be 1 - 79 characters",),;,expr,(,*,new_key,),[,expr,79,],assign_op,=,'\0',;,expr,key_len,assign_op,=,79,;,},return,(,key_len,),;,},
#
# cve-2007-5269-2.c.txt,void,function_name,png_handle_sCAL,(,parameter_decl,png_structp,png_ptr,,,parameter_decl,png_infop,info_ptr,,,parameter_decl,png_uint_32,length,),{,car_decl,png_charp,buffer,,,car_decl,png_charp,ep,;,car_decl,double,width,,,car_decl,double,height,;,car_decl,png_charp,vp,;,car_decl,png_charp,swidth,,,car_decl,png_charp,sheight,;,car_decl,png_size_t,slength,;,expr,function_call,callee,png_debug,(,argument,1,,,argument,"in png_handle_sCAL\n",),;,if,(,expr,!,(,png_ptr,->,mode,&,PNG_HAVE_IHDR,),),expr,function_call,callee,png_error,(,argument,png_ptr,,,argument,"Missing IHDR before sCAL",),;,else,if,(,expr,png_ptr,->,mode,&,PNG_HAVE_IDAT,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Invalid sCAL after IDAT",),;,expr,function_call,callee,png_crc_finish,(,argument,png_ptr,,,argument,length,),;,return,DESTINATION,;,},else,if,(,expr,expr,info_ptr,!=,NULL,&&,expr,(,info_ptr,->,valid,&,PNG_INFO_sCAL,),),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Duplicate sCAL chunk",),;,expr,function_call,callee,png_crc_finish,(,argument,png_ptr,,,argument,length,),;,return,DESTINATION,;,},expr,function_call,callee,png_debug1,(,argument,2,,,argument,"Allocating and reading sCAL chunk data (%lu bytes)\n",,,argument,length,+,1,),;,expr,buffer,assign_op,=,(,png_charp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,length,+,1,),;,if,(,expr,buffer,==,NULL,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Out of memory while processing sCAL chunk",),;,return,DESTINATION,;,},expr,slength,assign_op,=,(,png_size_t,),length,;,expr,function_call,callee,png_crc_read,(,argument,png_ptr,,,argument,(,png_bytep,),buffer,,,argument,slength,),;,if,(,expr,function_call,callee,png_crc_finish,(,argument,png_ptr,,,argument,0,),),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,buffer,),;,return,DESTINATION,;,},expr,buffer,[,expr,slength,],assign_op,=,0x00,;,expr,ep,assign_op,=,buffer,+,1,;,expr,width,assign_op,=,function_call,callee,strtod,(,argument,ep,,,argument,&,vp,),;,if,(,expr,*,vp,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"malformed width string in sCAL chunk",),;,return,DESTINATION,;,},expr,swidth,assign_op,=,(,png_charp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,function_call,callee,png_strlen,(,argument,ep,),+,1,),;,if,(,expr,swidth,==,NULL,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Out of memory while processing sCAL chunk width",),;,return,DESTINATION,;,},expr,function_call,callee,png_memcpy,(,argument,swidth,,,argument,ep,,,argument,(,png_size_t,),function_call,callee,png_strlen,(,argument,ep,),),;,iteration,for,(,expr,ep,assign_op,=,buffer,;,expr,*,ep,;,expr,ep,++,),;,expr,ep,++,;,expr,height,assign_op,=,function_call,callee,strtod,(,argument,ep,,,argument,&,vp,),;,if,(,expr,*,vp,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"malformed height string in sCAL chunk",),;,return,DESTINATION,;,},expr,sheight,assign_op,=,(,png_charp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,function_call,callee,png_strlen,(,argument,ep,),+,1,),;,if,(,expr,swidth,==,NULL,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Out of memory while processing sCAL chunk height",),;,return,DESTINATION,;,},expr,function_call,callee,png_memcpy,(,argument,sheight,,,argument,ep,,,argument,(,png_size_t,),function_call,callee,png_strlen,(,argument,ep,),),;,if,(,expr,expr,buffer,+,slength,<,ep,||,expr,expr,width,<=,0.,||,expr,height,<=,0.,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Invalid sCAL data",),;,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,buffer,),;,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,swidth,),;,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,sheight,),;,return,DESTINATION,;,},expr,function_call,callee, ...
#
# cve-2006-7244.c.txt,void,function_name,png_write_iCCP,(,parameter_decl,png_structp,png_ptr,,,parameter_decl,png_charp,name,,,parameter_decl,int,compression_type,,,parameter_decl,png_charp,profile,,,parameter_decl,int,profile_len,),{,expr,PNG_iCCP,;,car_decl,png_size_t,name_len,;,car_decl,png_charp,new_name,;,car_decl,compression_state,comp,;,expr,function_call,callee,png_debug,(,argument,1,,,argument,"in png_write_iCCP\n",),;,expr,comp,.,num_output_ptr,assign_op,=,0,;,expr,comp,.,max_output_ptr,assign_op,=,0,;,expr,comp,.,output_ptr,assign_op,=,NULL,;,expr,comp,.,input,assign_op,=,NULL,;,expr,comp,.,input_len,assign_op,=,0,;,if,(,expr,expr,name,==,NULL,||,expr,(,name_len,assign_op,=,function_call,callee,png_check_keyword,(,argument,png_ptr,,,argument,name,,,argument,&,new_name,),),==,0,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Empty keyword in iCCP chunk",),;,return,DESTINATION,;,},if,(,expr,compression_type,!=,PNG_COMPRESSION_TYPE_BASE,),expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Unknown compression type in iCCP chunk",),;,if,(,expr,profile,==,NULL,),expr,profile_len,assign_op,=,0,;,if,(,expr,profile_len,),expr,profile_len,assign_op,=,function_call,callee,png_text_compress,(,argument,png_ptr,,,argument,profile,,,argument,(,png_size_t,),profile_len,,,argument,PNG_COMPRESSION_TYPE_BASE,,,argument,&,comp,),;,expr,function_call,callee,png_write_chunk_start,(,argument,png_ptr,,,argument,(,png_bytep,),png_iCCP,,,argument,(,png_uint_32,),name_len,+,profile_len,+,2,),;,expr,new_name,[,expr,name_len,+,1,],assign_op,=,0x00,;,expr,function_call,callee,png_write_chunk_data,(,argument,png_ptr,,,argument,(,png_bytep,),new_name,,,argument,name_len,+,2,),;,if,(,expr,profile_len,),expr,function_call,callee,png_write_compressed_data_out,(,argument,png_ptr,,,argument,&,comp,),;,expr,function_call,callee,png_write_chunk_end,(,argument,png_ptr,),;,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,new_name,),;,},
#
# cve-2008-5907.c.txt,png_size_t,function_name,png_check_keyword,(,parameter_decl,png_structp,png_ptr,,,parameter_decl,png_charp,key,,,parameter_decl,png_charpp,new_key,),{,car_decl,png_size_t,key_len,;,car_decl,png_charp,kp,,,car_decl,png_charp,dp,;,car_decl,int,kflag,;,car_decl,int,kwarn,;,kwarn,assign_op,=,0,;,expr,function_call,callee,png_debug,(,argument,1,,,argument,"in png_check_keyword\n",),;,expr,*,new_key,assign_op,=,NULL,;,if,(,expr,expr,key,==,NULL,||,expr,(,key_len,assign_op,=,function_call,callee,png_strlen,(,argument,key,),),==,0,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"zero length keyword",),;,return,expr,(,(,png_size_t,),0,),;,},expr,function_call,callee,png_debug1,(,argument,2,,,argument,"Keyword to be checked is '%s'\n",,,argument,key,),;,expr,*,new_key,assign_op,=,(,png_charp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,(,png_uint_32,),(,key_len,+,2,),),;,if,(,expr,*,new_key,==,NULL,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Out of memory while procesing keyword",),;,return,expr,(,(,png_size_t,),0,),;,},iteration,for,(,expr,kp,assign_op,=,key,,,dp,assign_op,=,*,new_key,;,expr,*,kp,!=,'\0',;,expr,kp,++,,,dp,++,),{,if,(,expr,expr,(,png_byte,),*,kp,<,0x20,||,expr,(,expr,(,png_byte,),*,kp,>,0x7E,&&,expr,(,png_byte,),*,kp,<,0xA1,),),{,car_decl,char,[,40,],msg,;,expr,function_call,callee,png_snprintf,(,argument,msg,,,argument,40,,,argument,"invalid keyword character 0x%02X",,,argument,(,png_byte,),*,kp,),;,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,msg,),;,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"invalid character in keyword",),;,expr,*,dp,assign_op,=,' ',;,},else,{,expr,*,dp,assign_op,=,*,kp,;,},},expr,*,dp,assign_op,=,'\0',;,expr,kp,assign_op,=,*,new_key,+,key_len,-,1,;,if,(,expr,*,kp,==,' ',),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"trailing spaces removed from keyword",),;,iteration,while,(,expr,*,kp,==,' ',),{,expr,*,(,kp,--,),assign_op,=,'\0',;,expr,key_len,--,;,},},expr,kp,assign_op,=,*,new_key,;,if,(,expr,*,kp,==,' ',),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"leading spaces removed from keyword",),;,iteration,while,(,expr,*,kp,==,' ',),{,expr,kp,++,;,expr,key_len,--,;,},},expr,function_call,callee,png_debug1,(,argument,2,,,argument,"Checking for multiple internal spaces in '%s'\n",,,argument,kp,),;,iteration,for,(,expr,kflag,assign_op,=,0,,,dp,assign_op,=,*,new_key,;,expr,*,kp,!=,'\0',;,expr,kp,++,),{,if,(,expr,expr,*,kp,==,' ',&&,expr,kflag,==,0,),{,expr,*,(,dp,++,),assign_op,=,*,kp,;,expr,kflag,assign_op,=,1,;,},else,if,(,expr,*,kp,==,' ',),{,expr,key_len,--,;,expr,kwarn,assign_op,=,1,;,},else,{,expr,*,(,dp,++,),assign_op,=,*,kp,;,expr,kflag,assign_op,=,0,;,},},expr,*,dp,assign_op,=,'\0',;,if,(,expr,kwarn,),expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"extra interior spaces removed from keyword",),;,if,(,expr,key_len,==,0,),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,*,new_key,),;,expr,*,new_key,assign_op,=,NULL,;,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Zero length keyword",),;,},if,(,expr,key_len,>,79,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"keyword length must be 1 - 79 characters",),;,expr,new_key,[,expr,79,],assign_op,=,'\0',;,expr,key_len,assign_op,=,79,;,},return,(,key_len,),;,},
#
# cve-2007-5629-3.c.txt,void,function_name,png_handle_iTXt,(,parameter_decl,png_structp,png_ptr,,,parameter_decl,png_infop,info_ptr,,,parameter_decl,png_uint_32,length,),{,car_decl,png_textp,text_ptr,;,car_decl,png_charp,chunkdata,;,car_decl,png_charp,key,,,car_decl,png_charp,lang,,,car_decl,png_charp,text,,,car_decl,png_charp,lang_key,;,car_decl,int,comp_flag,;,car_decl,int,comp_type,;,comp_type,assign_op,=,0,;,car_decl,int,ret,;,car_decl,png_size_t,slength,,,car_decl,png_size_t,prefix_len,,,car_decl,png_size_t,data_len,;,expr,function_call,callee,png_debug,(,argument,1,,,argument,"in png_handle_iTXt\n",),;,if,(,expr,!,(,png_ptr,->,mode,&,PNG_HAVE_IHDR,),),expr,function_call,callee,png_error,(,argument,png_ptr,,,argument,"Missing IHDR before iTXt",),;,if,(,expr,png_ptr,->,mode,&,PNG_HAVE_IDAT,),expr,png_ptr,->,mode,assign_op,|=,PNG_AFTER_IDAT,;,if,(,expr,length,>,(,png_uint_32,),65535L,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"iTXt chunk too large to fit in memory",),;,expr,function_call,callee,png_crc_finish,(,argument,png_ptr,,,argument,length,),;,return,DESTINATION,;,},expr,chunkdata,assign_op,=,(,png_charp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,length,+,1,),;,if,(,expr,chunkdata,==,NULL,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"No memory to process iTXt chunk.",),;,return,DESTINATION,;,},expr,slength,assign_op,=,(,png_size_t,),length,;,expr,function_call,callee,png_crc_read,(,argument,png_ptr,,,argument,(,png_bytep,),chunkdata,,,argument,slength,),;,if,(,expr,function_call,callee,png_crc_finish,(,argument,png_ptr,,,argument,0,),),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,chunkdata,),;,return,DESTINATION,;,},expr,chunkdata,[,expr,slength,],assign_op,=,0x00,;,iteration,for,(,expr,lang,assign_op,=,chunkdata,;,expr,*,lang,;,expr,lang,++,),;,expr,lang,++,;,if,(,expr,lang,>=,chunkdata,+,slength,),{,expr,comp_flag,assign_op,=,PNG_TEXT_COMPRESSION_NONE,;,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Zero length iTXt chunk",),;,},else,{,expr,comp_flag,assign_op,=,*,lang,++,;,expr,comp_type,assign_op,=,*,lang,++,;,},iteration,for,(,expr,lang_key,assign_op,=,lang,;,expr,*,lang_key,;,expr,lang_key,++,),;,expr,lang_key,++,;,iteration,for,(,expr,text,assign_op,=,lang_key,;,expr,*,text,;,expr,text,++,),;,expr,text,++,;,expr,prefix_len,assign_op,=,text,-,chunkdata,;,expr,key,assign_op,=,chunkdata,;,if,(,expr,comp_flag,),expr,chunkdata,assign_op,=,function_call,callee,png_decompress_chunk,(,argument,png_ptr,,,argument,comp_type,,,argument,chunkdata,,,argument,(,size_t,),length,,,argument,prefix_len,,,argument,&,data_len,),;,else,expr,data_len,assign_op,=,function_call,callee,png_strlen,(,argument,chunkdata,+,prefix_len,),;,expr,text_ptr,assign_op,=,(,png_textp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,(,png_uint_32,),function_call,callee,png_sizeof,(,argument,png_text,),),;,if,(,expr,text_ptr,==,NULL,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Not enough memory to process iTXt chunk.",),;,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,chunkdata,),;,return,DESTINATION,;,},expr,text_ptr,->,compression,assign_op,=,(,int,),comp_flag,+,1,;,expr,text_ptr,->,lang_key,assign_op,=,chunkdata,+,(,lang_key,-,key,),;,expr,text_ptr,->,lang,assign_op,=,chunkdata,+,(,lang,-,key,),;,expr,text_ptr,->,itxt_length,assign_op,=,data_len,;,expr,text_ptr,->,text_length,assign_op,=,0,;,expr,text_ptr,->,key,assign_op,=,chunkdata,;,expr,text_ptr,->,text,assign_op,=,chunkdata,+,prefix_len,;,expr,ret,assign_op,=,function_call,callee,png_set_text_2,(,argument,png_ptr,,,argument,info_ptr,,,argument,text_ptr,,,argument,1,),;,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,text_ptr,),;,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,chunkdata,),;,if,(,expr,ret,),expr,function_call,callee,png_error,(,argument,png_ptr,,,argument,"I ...
#
# cve-2014-0333.c.txt,void,function_name,png_push_read_chunk,(,parameter_decl,png_structrp,png_ptr,,,parameter_decl,png_inforp,info_ptr,),{,car_decl,png_uint_32,chunk_name,;,car_decl,int,keep,;,if,(,expr,!,(,png_ptr,->,mode,&,PNG_HAVE_CHUNK_HEADER,),),{,car_decl,png_byte,[,4,],chunk_length,;,car_decl,png_byte,[,4,],chunk_tag,;,if,(,expr,png_ptr,->,buffer_size,<,8,),{,expr,function_call,callee,png_push_save_buffer,(,argument,png_ptr,),;,return,DESTINATION,;,},expr,function_call,callee,png_push_fill_buffer,(,argument,png_ptr,,,argument,chunk_length,,,argument,4,),;,expr,png_ptr,->,push_length,assign_op,=,function_call,callee,png_get_uint_31,(,argument,png_ptr,,,argument,chunk_length,),;,expr,function_call,callee,png_reset_crc,(,argument,png_ptr,),;,expr,function_call,callee,png_crc_read,(,argument,png_ptr,,,argument,chunk_tag,,,argument,4,),;,expr,png_ptr,->,chunk_name,assign_op,=,function_call,callee,PNG_CHUNK_FROM_STRING,(,argument,chunk_tag,),;,expr,function_call,callee,png_check_chunk_name,(,argument,png_ptr,,,argument,png_ptr,->,chunk_name,),;,expr,png_ptr,->,mode,assign_op,|=,PNG_HAVE_CHUNK_HEADER,;,},expr,chunk_name,assign_op,=,png_ptr,->,chunk_name,;,if,(,expr,chunk_name,==,png_IDAT,),{,if,(,expr,png_ptr,->,mode,&,PNG_AFTER_IDAT,),expr,png_ptr,->,mode,assign_op,|=,PNG_HAVE_CHUNK_AFTER_IDAT,;,if,(,expr,!,(,png_ptr,->,mode,&,PNG_HAVE_IHDR,),),expr,function_call,callee,png_error,(,argument,png_ptr,,,argument,"Missing IHDR before IDAT",),;,else,if,(,expr,expr,png_ptr,->,color_type,==,PNG_COLOR_TYPE_PALETTE,&&,expr,!,(,png_ptr,->,mode,&,PNG_HAVE_PLTE,),),expr,function_call,callee,png_error,(,argument,png_ptr,,,argument,"Missing PLTE before IDAT",),;,expr,png_ptr,->,mode,assign_op,|=,PNG_HAVE_IDAT,;,if,(,expr,!,(,png_ptr,->,mode,&,PNG_HAVE_CHUNK_AFTER_IDAT,),),if,(,expr,png_ptr,->,push_length,==,0,),return,DESTINATION,;,if,(,expr,png_ptr,->,mode,&,PNG_AFTER_IDAT,),expr,function_call,callee,png_benign_error,(,argument,png_ptr,,,argument,"Too many IDATs found",),;,},if,(,expr,chunk_name,==,png_IHDR,),{,if,(,expr,png_ptr,->,push_length,!=,13,),expr,function_call,callee,png_error,(,argument,png_ptr,,,argument,"Invalid IHDR length",),;,if,(,expr,png_ptr,->,push_length,+,4,>,png_ptr,->,buffer_size,),{,expr,function_call,callee,png_push_save_buffer,(,argument,png_ptr,),;,return,DESTINATION,;,},expr,function_call,callee,png_handle_IHDR,(,argument,png_ptr,,,argument,info_ptr,,,argument,png_ptr,->,push_length,),;,},else,if,(,expr,chunk_name,==,png_IEND,),{,if,(,expr,png_ptr,->,push_length,+,4,>,png_ptr,->,buffer_size,),{,expr,function_call,callee,png_push_save_buffer,(,argument,png_ptr,),;,return,DESTINATION,;,},expr,function_call,callee,png_handle_IEND,(,argument,png_ptr,,,argument,info_ptr,,,argument,png_ptr,->,push_length,),;,expr,png_ptr,->,process_mode,assign_op,=,PNG_READ_DONE_MODE,;,expr,function_call,callee,png_push_have_end,(,argument,png_ptr,,,argument,info_ptr,),;,},else,if,(,expr,(,keep,assign_op,=,function_call,callee,png_chunk_unknown_handling,(,argument,png_ptr,,,argument,chunk_name,),),!=,0,),{,if,(,expr,png_ptr,->,push_length,+,4,>,png_ptr,->,buffer_size,),{,expr,function_call,callee,png_push_save_buffer,(,argument,png_ptr,),;,return,DESTINATION,;,},expr,function_call,callee,png_handle_unknown,(,argument,png_ptr,,,argument,info_ptr,,,argument,png_ptr,->,push_length,,,argument,keep,),;,if,(,expr,chunk_name,==,png_PLTE,),expr,png_ptr,->,mode,assign_op,|=,PNG_HAVE_PLTE,;,},else,if,(,expr,chunk_name,==,png_PLTE,),{,if,(,expr,png_ptr,->,push_length,+,4,>,png_ptr,->,buffer_size,),{,expr,function_call,callee,png_push_save_buffer,(,argument,png_ptr,),;,return,DESTINATION,;,},expr,function_call,callee,png_handle_PLTE,(,argument,png_ptr,,,argument,info_ptr,,,argument,png_ptr,->,push_length,),;,},else,if,(,expr,chunk_name,==,png_IDAT,),{,expr,png_ptr,->,idat_size,assign_op,=,png_ptr,->,push_length,;,expr,png_ptr,->,process_mode,assign_op,=,PNG_READ_IDAT_MODE,;,expr,function_call,callee,png_push_have_info,(,argument,png_ptr,,,argumen ...
#
# cve-2007-5267.c.txt,PNGAPI,function_name,png_set_iCCP,(,parameter_decl,png_structp,png_ptr,,,parameter_decl,png_infop,info_ptr,,,parameter_decl,png_charp,name,,,parameter_decl,int,compression_type,,,parameter_decl,png_charp,profile,,,parameter_decl,png_uint_32,proflen,),{,car_decl,png_charp,new_iccp_name,;,car_decl,png_charp,new_iccp_profile,;,expr,function_call,callee,png_debug1,(,argument,1,,,argument,"in %s storage function\n",,,argument,"iCCP",),;,if,(,expr,expr,png_ptr,==,NULL,||,expr,expr,info_ptr,==,NULL,||,expr,expr,name,==,NULL,||,expr,profile,==,NULL,),return,DESTINATION,;,expr,new_iccp_name,assign_op,=,(,png_charp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,function_call,callee,png_strlen,(,argument,name,),+,1,),;,if,(,expr,new_iccp_name,==,NULL,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Insufficient memory to process iCCP chunk.",),;,return,DESTINATION,;,},expr,function_call,callee,png_strcpy,(,argument,new_iccp_name,,,argument,name,),;,expr,new_iccp_profile,assign_op,=,(,png_charp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,proflen,),;,if,(,expr,new_iccp_profile,==,NULL,),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,new_iccp_name,),;,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Insufficient memory to process iCCP profile.",),;,return,DESTINATION,;,},expr,function_call,callee,png_memcpy,(,argument,new_iccp_profile,,,argument,profile,,,argument,(,png_size_t,),proflen,),;,expr,function_call,callee,png_free_data,(,argument,png_ptr,,,argument,info_ptr,,,argument,PNG_FREE_ICCP,,,argument,0,),;,expr,info_ptr,->,iccp_proflen,assign_op,=,proflen,;,expr,info_ptr,->,iccp_name,assign_op,=,new_iccp_name,;,expr,info_ptr,->,iccp_profile,assign_op,=,new_iccp_profile,;,expr,info_ptr,->,iccp_compression,assign_op,=,(,png_byte,),compression_type,;,expr,info_ptr,->,free_me,assign_op,|=,PNG_FREE_ICCP,;,expr,info_ptr,->,valid,assign_op,|=,PNG_INFO_iCCP,;,},
#
# ...
#
# cve-2008-6218.c.txt,void,function_name,png_handle_tEXt,(,parameter_decl,png_structp,png_ptr,,,parameter_decl,png_infop,info_ptr,,,parameter_decl,png_uint_32,length,),{,car_decl,png_textp,text_ptr,;,car_decl,png_charp,key,;,car_decl,png_charp,text,;,car_decl,png_uint_32,skip,;,skip,assign_op,=,0,;,car_decl,png_size_t,slength,;,car_decl,int,ret,;,expr,function_call,callee,png_debug,(,argument,1,,,argument,"in png_handle_tEXt\n",),;,if,(,expr,!,(,png_ptr,->,mode,&,PNG_HAVE_IHDR,),),expr,function_call,callee,png_error,(,argument,png_ptr,,,argument,"Missing IHDR before tEXt",),;,if,(,expr,png_ptr,->,mode,&,PNG_HAVE_IDAT,),expr,png_ptr,->,mode,assign_op,|=,PNG_AFTER_IDAT,;,if,(,expr,length,>,(,png_uint_32,),65535L,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"tEXt chunk too large to fit in memory",),;,expr,skip,assign_op,=,length,-,(,png_uint_32,),65535L,;,expr,length,assign_op,=,(,png_uint_32,),65535L,;,},expr,key,assign_op,=,(,png_charp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,length,+,1,),;,if,(,expr,key,==,NULL,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"No memory to process text chunk.",),;,return,DESTINATION,;,},expr,slength,assign_op,=,(,png_size_t,),length,;,expr,function_call,callee,png_crc_read,(,argument,png_ptr,,,argument,(,png_bytep,),key,,,argument,slength,),;,if,(,expr,function_call,callee,png_crc_finish,(,argument,png_ptr,,,argument,skip,),),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,key,),;,return,DESTINATION,;,},expr,key,[,expr,slength,],assign_op,=,0x00,;,iteration,for,(,expr,text,assign_op,=,key,;,expr,*,text,;,expr,text,++,),;,if,(,expr,text,!=,key,+,slength,),expr,text,++,;,expr,text_ptr,assign_op,=,(,png_textp,),function_call,callee,png_malloc_warn,(,argument,png_ptr,,,argument,(,png_uint_32,),function_call,callee,png_sizeof,(,argument,png_text,),),;,if,(,expr,text_ptr,==,NULL,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Not enough memory to process text chunk.",),;,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,key,),;,return,DESTINATION,;,},expr,text_ptr,->,compression,assign_op,=,PNG_TEXT_COMPRESSION_NONE,;,expr,text_ptr,->,key,assign_op,=,key,;,expr,text_ptr,->,lang,assign_op,=,NULL,;,expr,text_ptr,->,lang_key,assign_op,=,NULL,;,expr,text_ptr,->,itxt_length,assign_op,=,0,;,expr,text_ptr,->,text,assign_op,=,text,;,expr,text_ptr,->,text_length,assign_op,=,function_call,callee,png_strlen,(,argument,text,),;,expr,ret,assign_op,=,function_call,callee,png_set_text_2,(,argument,png_ptr,,,argument,info_ptr,,,argument,text_ptr,,,argument,1,),;,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,key,),;,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,text_ptr,),;,if,(,expr,ret,),expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Insufficient memory to process text chunk.",),;,},
#
# cve-2011-0408-1.c.txt,void,function_name,png_do_expand_palette,(,parameter_decl,png_row_infop,row_info,,,parameter_decl,png_bytep,row,,,parameter_decl,png_const_colorp,palette,,,parameter_decl,png_const_bytep,trans_alpha,,,parameter_decl,int,num_trans,),{,car_decl,int,shift,,,car_decl,int,value,;,car_decl,png_bytep,sp,,,car_decl,png_bytep,dp,;,car_decl,png_uint_32,i,;,car_decl,png_uint_32,row_width,;,row_width,assign_op,=,row_info,->,width,;,expr,function_call,callee,png_debug,(,argument,1,,,argument,"in png_do_expand_palette",),;,if,(,expr,row_info,->,color_type,==,PNG_COLOR_TYPE_PALETTE,),{,if,(,expr,row_info,->,bit_depth,<,8,),{,switch,(,expr,row_info,->,bit_depth,),{,case,1,:,{,expr,sp,assign_op,=,row,+,(,png_size_t,),(,(,row_width,-,1,),>>,3,),;,expr,dp,assign_op,=,row,+,(,png_size_t,),row_width,-,1,;,expr,shift,assign_op,=,7,-,(,int,),(,(,row_width,+,7,),&,0x07,),;,iteration,for,(,expr,i,assign_op,=,0,;,expr,i,<,row_width,;,expr,i,++,),{,if,(,expr,(,*,sp,>>,shift,),&,0x01,),expr,*,dp,assign_op,=,1,;,else,expr,*,dp,assign_op,=,0,;,if,(,expr,shift,==,7,),{,expr,shift,assign_op,=,0,;,expr,sp,--,;,},else,expr,shift,++,;,expr,dp,--,;,},break,DESTINATION,;,},case,2,:,{,expr,sp,assign_op,=,row,+,(,png_size_t,),(,(,row_width,-,1,),>>,2,),;,expr,dp,assign_op,=,row,+,(,png_size_t,),row_width,-,1,;,expr,shift,assign_op,=,(,int,),(,(,3,-,(,(,row_width,+,3,),&,0x03,),),<<,1,),;,iteration,for,(,expr,i,assign_op,=,0,;,expr,i,<,row_width,;,expr,i,++,),{,expr,value,assign_op,=,(,*,sp,>>,shift,),&,0x03,;,expr,*,dp,assign_op,=,(,png_byte,),value,;,if,(,expr,shift,==,6,),{,expr,shift,assign_op,=,0,;,expr,sp,--,;,},else,expr,shift,assign_op,+=,2,;,expr,dp,--,;,},break,DESTINATION,;,},case,4,:,{,expr,sp,assign_op,=,row,+,(,png_size_t,),(,(,row_width,-,1,),>>,1,),;,expr,dp,assign_op,=,row,+,(,png_size_t,),row_width,-,1,;,expr,shift,assign_op,=,(,int,),(,(,row_width,&,0x01,),<<,2,),;,iteration,for,(,expr,i,assign_op,=,0,;,expr,i,<,row_width,;,expr,i,++,),{,expr,value,assign_op,=,(,*,sp,>>,shift,),&,0x0f,;,expr,*,dp,assign_op,=,(,png_byte,),value,;,if,(,expr,shift,==,4,),{,expr,shift,assign_op,=,0,;,expr,sp,--,;,},else,expr,shift,assign_op,+=,4,;,expr,dp,--,;,},break,DESTINATION,;,},default,:,break,DESTINATION,;,},expr,row_info,->,bit_depth,assign_op,=,8,;,expr,row_info,->,pixel_depth,assign_op,=,8,;,expr,row_info,->,rowbytes,assign_op,=,row_width,;,},else,if,(,expr,row_info,->,bit_depth,==,8,),{,{,if,(,expr,trans_alpha,!=,NULL,),{,expr,sp,assign_op,=,row,+,(,png_size_t,),row_width,-,1,;,expr,dp,assign_op,=,row,+,(,png_size_t,),(,row_width,<<,2,),-,1,;,iteration,for,(,expr,i,assign_op,=,0,;,expr,i,<,row_width,;,expr,i,++,),{,if,(,expr,(,int,),(,*,sp,),>=,num_trans,),expr,*,dp,--,assign_op,=,0xff,;,else,expr,*,dp,--,assign_op,=,trans_alpha,[,expr,*,sp,],;,expr,*,dp,--,assign_op,=,palette,[,expr,*,sp,],.,blue,;,expr,*,dp,--,assign_op,=,palette,[,expr,*,sp,],.,green,;,expr,*,dp,--,assign_op,=,palette,[,expr,*,sp,],.,red,;,expr,sp,--,;,},expr,row_info,->,bit_depth,assign_op,=,8,;,expr,row_info,->,pixel_depth,assign_op,=,32,;,expr,row_info,->,rowbytes,assign_op,=,row_width,*,4,;,expr,row_info,->,color_type,assign_op,=,6,;,expr,row_info,->,channels,assign_op,=,4,;,},else,{,expr,sp,assign_op,=,row,+,(,png_size_t,),row_width,-,1,;,expr,dp,assign_op,=,row,+,(,png_size_t,),(,row_width,*,3,),-,1,;,iteration,for,(,expr,i,assign_op,=,0,;,expr,i,<,row_width,;,expr,i,++,),{,expr,*,dp,--,assign_op,=,palette,[,expr,*,sp,],.,blue,;,expr,*,dp,--,assign_op,=,palette,[,expr,*,sp,],.,green,;,expr,*,dp,--,assign_op,=,palette,[,expr,*,sp,],.,red,;,expr,sp,--,;,},expr,row_info,->,bit_depth,assign_op,=,8,;,expr,row_info,->,pixel_depth,assign_op,=,24,;,expr,row_info,->,rowbytes,assign_op,=,row_width,*,3,;,expr,row_info,->,color_type,assign_op,=,2,;,expr,row_info,->,channels,assign_op,=,3,;,},},},},},
#
# cve-2009-5063.c.txt,void,function_name,png_write_iCCP,(,parameter_decl,png_structp,png_ptr,,,parameter_decl,png_const_charp,name,,,parameter_decl,int,compression_type,,,parameter_decl,png_const_charp,profile,,,parameter_decl,int,profile_len,),{,expr,PNG_iCCP,;,car_decl,png_size_t,name_len,;,car_decl,png_charp,new_name,;,car_decl,compression_state,comp,;,car_decl,int,embedded_profile_len,;,embedded_profile_len,assign_op,=,0,;,expr,function_call,callee,png_debug,(,argument,1,,,argument,"in png_write_iCCP",),;,expr,comp,.,num_output_ptr,assign_op,=,0,;,expr,comp,.,max_output_ptr,assign_op,=,0,;,expr,comp,.,output_ptr,assign_op,=,NULL,;,expr,comp,.,input,assign_op,=,NULL,;,expr,comp,.,input_len,assign_op,=,0,;,if,(,expr,(,name_len,assign_op,=,function_call,callee,png_check_keyword,(,argument,png_ptr,,,argument,name,,,argument,&,new_name,),),==,0,),return,DESTINATION,;,if,(,expr,compression_type,!=,PNG_COMPRESSION_TYPE_BASE,),expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Unknown compression type in iCCP chunk",),;,if,(,expr,profile,==,NULL,),expr,profile_len,assign_op,=,0,;,if,(,expr,profile_len,>,3,),expr,embedded_profile_len,assign_op,=,(,(,*,(,(,png_const_bytep,),profile,),),<<,24,),|,(,(,*,(,(,png_const_bytep,),profile,+,1,),),<<,16,),|,(,(,*,(,(,png_const_bytep,),profile,+,2,),),<<,8,),|,(,(,*,(,(,png_const_bytep,),profile,+,3,),),),;,if,(,expr,embedded_profile_len,<,0,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Embedded profile length in iCCP chunk is negative",),;,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,new_name,),;,return,DESTINATION,;,},if,(,expr,profile_len,<,embedded_profile_len,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Embedded profile length too large in iCCP chunk",),;,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,new_name,),;,return,DESTINATION,;,},if,(,expr,profile_len,>,embedded_profile_len,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Truncating profile to actual length in iCCP chunk",),;,expr,profile_len,assign_op,=,embedded_profile_len,;,},if,(,expr,profile_len,),expr,profile_len,assign_op,=,function_call,callee,png_text_compress,(,argument,png_ptr,,,argument,profile,,,argument,(,png_size_t,),profile_len,,,argument,PNG_COMPRESSION_TYPE_BASE,,,argument,&,comp,),;,expr,function_call,callee,png_write_chunk_start,(,argument,png_ptr,,,argument,png_iCCP,,,argument,(,png_uint_32,),(,name_len,+,profile_len,+,2,),),;,expr,new_name,[,expr,name_len,+,1,],assign_op,=,0x00,;,expr,function_call,callee,png_write_chunk_data,(,argument,png_ptr,,,argument,(,png_bytep,),new_name,,,argument,(,png_size_t,),(,name_len,+,2,),),;,if,(,expr,profile_len,),expr,function_call,callee,png_write_compressed_data_out,(,argument,png_ptr,,,argument,&,comp,),;,expr,function_call,callee,png_write_chunk_end,(,argument,png_ptr,),;,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,new_name,),;,},
#
# cve-2004-0598.c.txt,void,function_name,png_handle_iCCP,(,parameter_decl,png_structp,png_ptr,,,parameter_decl,png_infop,info_ptr,,,parameter_decl,png_uint_32,length,),{,car_decl,png_charp,chunkdata,;,car_decl,png_byte,compression_type,;,car_decl,png_bytep,pC,;,car_decl,png_charp,profile,;,car_decl,png_uint_32,skip,;,skip,assign_op,=,0,;,car_decl,png_uint_32,profile_size,,,car_decl,png_uint_32,profile_length,;,car_decl,png_size_t,slength,,,car_decl,png_size_t,prefix_length,,,car_decl,png_size_t,data_length,;,expr,function_call,callee,png_debug,(,argument,1,,,argument,"in png_handle_iCCP\n",),;,if,(,expr,!,(,png_ptr,->,mode,&,PNG_HAVE_IHDR,),),expr,function_call,callee,png_error,(,argument,png_ptr,,,argument,"Missing IHDR before iCCP",),;,else,if,(,expr,png_ptr,->,mode,&,PNG_HAVE_IDAT,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Invalid iCCP after IDAT",),;,expr,function_call,callee,png_crc_finish,(,argument,png_ptr,,,argument,length,),;,return,DESTINATION,;,},else,if,(,expr,png_ptr,->,mode,&,PNG_HAVE_PLTE,),expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Out of place iCCP chunk",),;,if,(,expr,expr,info_ptr,!=,NULL,&&,expr,(,info_ptr,->,valid,&,PNG_INFO_iCCP,),),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Duplicate iCCP chunk",),;,expr,function_call,callee,png_crc_finish,(,argument,png_ptr,,,argument,length,),;,return,DESTINATION,;,},if,(,expr,length,>,(,png_uint_32,),65535L,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"iCCP chunk too large to fit in memory",),;,expr,skip,assign_op,=,length,-,(,png_uint_32,),65535L,;,expr,length,assign_op,=,(,png_uint_32,),65535L,;,},expr,chunkdata,assign_op,=,(,png_charp,),function_call,callee,png_malloc,(,argument,png_ptr,,,argument,length,+,1,),;,expr,slength,assign_op,=,(,png_size_t,),length,;,expr,function_call,callee,png_crc_read,(,argument,png_ptr,,,argument,(,png_bytep,),chunkdata,,,argument,slength,),;,if,(,expr,function_call,callee,png_crc_finish,(,argument,png_ptr,,,argument,skip,),),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,chunkdata,),;,return,DESTINATION,;,},expr,chunkdata,[,expr,slength,],assign_op,=,0x00,;,iteration,for,(,expr,profile,assign_op,=,chunkdata,;,expr,*,profile,;,expr,profile,++,),;,expr,++,profile,;,if,(,expr,profile,>=,chunkdata,+,slength,-,1,),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,chunkdata,),;,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Malformed iCCP chunk",),;,return,DESTINATION,;,},expr,compression_type,assign_op,=,*,profile,++,;,if,(,expr,compression_type,),{,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Ignoring nonzero compression type in iCCP chunk",),;,expr,compression_type,assign_op,=,0x00,;,},expr,prefix_length,assign_op,=,profile,-,chunkdata,;,expr,chunkdata,assign_op,=,function_call,callee,png_decompress_chunk,(,argument,png_ptr,,,argument,compression_type,,,argument,chunkdata,,,argument,slength,,,argument,prefix_length,,,argument,&,data_length,),;,expr,profile_length,assign_op,=,data_length,-,prefix_length,;,if,(,expr,expr,prefix_length,>,data_length,||,expr,profile_length,<,4,),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,chunkdata,),;,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Profile size field missing from iCCP chunk",),;,return,DESTINATION,;,},expr,pC,assign_op,=,(,png_bytep,),(,chunkdata,+,prefix_length,),;,expr,profile_size,assign_op,=,(,(,*,(,pC,),),<<,24,),|,(,(,*,(,pC,+,1,),),<<,16,),|,(,(,*,(,pC,+,2,),),<<,8,),|,(,(,*,(,pC,+,3,),),),;,if,(,expr,profile_size,<,profile_length,),expr,profile_length,assign_op,=,profile_size,;,if,(,expr,profile_size,>,profile_length,),{,expr,function_call,callee,png_free,(,argument,png_ptr,,,argument,chunkdata,),;,expr,function_call,callee,png_warning,(,argument,png_ptr,,,argument,"Ignoring truncated iCCP profile.",),;,return,DESTINATION,;,},expr,function_call,call ...
#
# Totally, there are 45 files.
